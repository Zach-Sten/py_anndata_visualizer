# %% [markdown]
# # Py annotation visualizer
# Inspired by Xenium Explorer and CellxGene to do rapid visualization of omics data

# %%
# import packages
import py_anndata_visualizer as pyav
import squidpy as sq
import scanpy as sc

# %%
# Should work just like this
adata = sc.read_h5ad('path_to_your_data.h5ad')

# %%
# Create the interface:
pyav.create_adata_interface(adata, sample_id = 'core_id', figsize = (900, 700))

# %% [markdown]
# Fixed:
# - added in having more than the preset emebddings able to be loaded in (first 2 embeddings only)
# - autohide missing embeddings.
# - add drop down menu for genes and observations
# - auto drops opacity of annotations down to .3 when a gene is first loaded in so you can see it.
# - Click around minimap for navigation when zoomed in.
# - gene expression colormap now has adjustable min and max
#
# Priority fixes:
# - Dbscan still going off 'core_id' in it but need to change this so it accepts a sample ID determined by the user.
# - Add in light and dark mode for viewing the view port
# - Give observations an "outline" feature so we can see whats underneath our colored cell types.
# - be able to re-import other .obsm for different layouts previously saved.
# - add in ability to call different layers for GEX.
# - exported images need legend in them off to the side for whats being viewed.
#
# Minor fixes:
# - trouble in logic for layout window. (need to be able to have rows but not columns)
# - only cells being visualized should be subject to size change
# - Need to adjust the sizing logic so it scales with zoom.
# - add ability to increase zoom intensity.
#
# Big fixes/updates:
# - add in ability to use mudata.
# - make it so masks can be imported (granted they're aligned with data already)
# - masks need to track with cores in different layouts.
