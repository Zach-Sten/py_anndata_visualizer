# %% [markdown]
# # Py annotation visualizer
# Inspired by Xenium Explorer and CellxGene to do rapid visualization of omics data

# %%
# import packages
import py_anndata_visualizer as pyav
import squidpy as sq
import scanpy as sc

# %%
# Should work just like this
adata = sc.read_h5ad('path_to_your_data.h5ad')

# %%
# Create the interface:
pyav.create_adata_interface(adata, sample_id = 'core_id', figsize = (900, 700))

# %% [markdown]
# Idea that I want to add in here is some sort of spatial metric for changing gene expression. This will go under GEX or somewhere and will be a heatmap that we see as you go from a start point to end point with a width that can change and number of bins. We can visualize multiple genes at once with this heatmap and I think this would provide a unique perspective to look at the data especially as we mask cells.
